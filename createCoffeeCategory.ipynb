# %%
import pandas as pd

df = pd.read_excel("caffe_with_coffee.xlsx")  

unique_items = df.loc[df['Category'] == 'BEVERAGE', 'Item Desc'].unique()
print(unique_items)
# Out:
# ['QUA  MINERAL WATER(1000ML)' 'MASALA CHAI CUTTING' 'MOROCCAN MINT TEA'
#  'LEMON ICED TEA' 'COUNTRY LEMONADE' 'MIAMI MELONS'
#  'RED BULL ENERGY DRINK' 'PINK LEMONADE' 'BLACK CURRANT ICED TEA'
#  'CURRANT COOLER' 'CHAI LATTE' 'GREAT LAKES CREAM'
#  'ULTIMATE HOT CHOCOLATE' 'ORANGINA  (250ML)' 'EARL GREY' 'COOKIE CRUMBLE'
#  'STRAWBERRY ICED TEA' 'BERRY BLAST' 'COOL CALIFORNICA'
#  'QUA  MINERAL WATER(500ML)' 'TROPICAL SMOOTHIE'
#  'GREAT LAKES FLOATS W CHOC' 'GREAT LAKES FLOAT W VANILLA' 'CHAMOMILE TEA'
#  'LINDT HOT CHOCOLATE' '2 AXE TWIST' 'ADD CINNAMON FLAVOUR'
#  'ADD WHIPPED CREAM' 'BOTTLED WATER (1LITRE)' 'BANGERS N MASH'
#  'BERRY BULL' 'BLUEBERRY BRAIN FREEZER SHAKE' 'GINSENG PEACH TEA'
#  'BAHUT BERRY' 'GREEN TEA' 'APPLE PEAR N LIME' 'FRUIT FROM THE TROPICS'
#  'SUGARLESS LEMON ICE TEA' 'TOMATO CARROT N CELERY' 'GHANA HOT CHOCOLATE'
#  'CINNAMON APPLE TEA' '3 RED BULL' 'APPLE CARROT N GINGER JUICE'
#  'VARLHONA HOT CHOCOLATE' 'WHITE TEA' 'PEACHES N STRAWBERRIES'
# ...

# %%
import pandas as pd


coffee_items = [
    'BRAZIL BOURBONSANTOS (AULAIT)',
    'BRAZIL BOURBONSANTOS (REG)',
    'CAFE MIT SCHLAG',
    'CAFFE LATTE',
    'CAPPUCCINO',
    'CAPPUCCINO GRANDE',
    'COLUMBIAN SUP DCAFE (AU LAIT)',
    'COLUMBIAN SUP DCAFE (RGLR)',
    'COLUMBIAN SUPREMO (AULAIT)',
    'COLUMBIAN SUPREMO  (REG)',
    'CON PANNA',
    'COSTARICA TARAZU (AULAIT)',
    'COSTARICA TARRAZU (REG)',
    'DECAFFINATE COFFEE FRAPPE',
    'DOPPIO',
    'ESPRESSO',
    'ESPRESSO TRIOS',
    'ETHIOPIAN YIRGACHEFFE (REG)',
    'ETHOPIAN YIRGACHEFFE (AULAIT)',
    'GREAT LAKES FRAPPE',
    'GREAT LAKES-JAVA BLEND (AULAIT)',
    'GREAT LAKES-JAVA BLEND (REG)',
    'GREAT LAKES FLOATS W CHOC',
    'GREAT LAKES FLOAT W VANILLA',
    'GUATEMALA ANTIGUA (AULAIT)',
    'GUATEMALA ANTIGUA (REG)',
    'HAWAIIAN KONA FANCY (AU LAIT)',
    'HAWAIIAN KONA FANCY(REG)',
    'HOUSE BLEND DE CAFFE (AU LAIT)',
    'HOUSE BLEND DECAFF (REG)',
    'HOUSEBLEND FULLCITY (AU LAIT)',
    'HOUSEBLEND FULLCITY (REG)',
    'INDIAN PEABERRY (AULAIT)',
    'INDIAN PEABERRY (REG)',
    'IRISH COFFEE',
    'JAMAICAN BLUE MT (AU LAIT)',
    'JAMAICAN BLUE MT (REG)',
    'JAVA ESTATES (AULAIT)',
    'JAVA ESTATES (REG)',
    'KENYA AA  (REG)',
    'KENYA AA (AULAIT)',
    'MONSOON MALABAR (AULAIT)',
    'MONSOON MALABAR (REG)',
    'NEW ORLEANS BLUE  (AULAIT)',
    'NEW ORLEANS BLUE (REG)',
    'SUMATRA MANDHELING (AULAIT)',
    'SUMATRA MANDHELING (REG)',
    'THE CHOCO LATTE',
    'YEMENI GREAT LAKES (AULAIT)',
    'YEMENI GREAT LAKES (REG)'
]
    
df = pd.read_excel("caffe.xlsx")  

df['Item Desc'] = df['Item Desc'].str.strip()

df.loc[df['Item Desc'].isin(coffee_items), 'Category'] = 'COFFEE'

df['Date'] = pd.to_datetime(df['Date']).dt.date

df.to_excel("caffe_with_coffee.xlsx", index=False)
