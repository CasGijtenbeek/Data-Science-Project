# %%
import pandas as pd


coffee_items = [
    'BRAZIL BOURBONSANTOS (AULAIT)',
    'BRAZIL BOURBONSANTOS (REG)',
    'CAFE MIT SCHLAG',
    'CAFFE LATTE',
    'CAPPUCCINO',
    'CAPPUCCINO GRANDE',
    'COLUMBIAN SUP DCAFE (AU LAIT)',
    'COLUMBIAN SUP DCAFE (RGLR)',
    'COLUMBIAN SUPREMO (AULAIT)',
    'COLUMBIAN SUPREMO  (REG)',
    'CON PANNA',
    'COSTARICA TARAZU (AULAIT)',
    'COSTARICA TARRAZU (REG)',
    'DECAFFINATE COFFEE FRAPPE',
    'DOPPIO',
    'ESPRESSO',
    'ESPRESSO TRIOS',
    'ETHIOPIAN YIRGACHEFFE (REG)',
    'ETHOPIAN YIRGACHEFFE (AULAIT)',
    'GREAT LAKES FRAPPE',
    'GREAT LAKES-JAVA BLEND (AULAIT)',
    'GREAT LAKES-JAVA BLEND (REG)',
    'GREAT LAKES FLOATS W CHOC',
    'GREAT LAKES FLOAT W VANILLA',
    'GUATEMALA ANTIGUA (AULAIT)',
    'GUATEMALA ANTIGUA (REG)',
    'HAWAIIAN KONA FANCY (AU LAIT)',
    'HAWAIIAN KONA FANCY(REG)',
    'HOUSE BLEND DE CAFFE (AU LAIT)',
    'HOUSE BLEND DECAFF (REG)',
    'HOUSEBLEND FULLCITY (AU LAIT)',
    'HOUSEBLEND FULLCITY (REG)',
    'INDIAN PEABERRY (AULAIT)',
    'INDIAN PEABERRY (REG)',
    'IRISH COFFEE',
    'JAMAICAN BLUE MT (AU LAIT)',
    'JAMAICAN BLUE MT (REG)',
    'JAVA ESTATES (AULAIT)',
    'JAVA ESTATES (REG)',
    'KENYA AA  (REG)',
    'KENYA AA (AULAIT)',
    'MONSOON MALABAR (AULAIT)',
    'MONSOON MALABAR (REG)',
    'NEW ORLEANS BLUE  (AULAIT)',
    'NEW ORLEANS BLUE (REG)',
    'SUMATRA MANDHELING (AULAIT)',
    'SUMATRA MANDHELING (REG)',
    'THE CHOCO LATTE',
    'YEMENI GREAT LAKES (AULAIT)',
    'YEMENI GREAT LAKES (REG)'
]
    
df = pd.read_excel("caffe.xlsx")  

df['Item Desc'] = df['Item Desc'].str.strip()

df.loc[df['Item Desc'].isin(coffee_items), 'Category'] = 'COFFEE'

df['Date'] = pd.to_datetime(df['Date']).dt.date

df.to_excel("caffe_with_coffee.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[1], line 65
#      61 df.loc[df['Item Desc'].isin(coffee_items), 'Category'] = 'COFFEE'
#      63 df['Date'] = pd.to_datetime(df['Date']).dt.date
# ---> 65 df.to_excel("caffe_with_coffee.xlsx", index=False)
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/pandas/core/generic.py:2436, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2423 from pandas.io.formats.excel import ExcelFormatter
#    2425 formatter = ExcelFormatter(
#    2426     df,
#    2427     na_rep=na_rep,
#    (...)   2434     inf_rep=inf_rep,
#    2435 )
# -> 2436 formatter.write(
#    2437     excel_writer,
#    2438     sheet_name=sheet_name,
#    2439     startrow=startrow,
#    2440     startcol=startcol,
#    2441     freeze_panes=freeze_panes,
#    2442     engine=engine,
#    2443     storage_options=storage_options,
#    2444     engine_kwargs=engine_kwargs,
#    2445 )
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/pandas/io/formats/excel.py:962, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
# --> 962         writer.close()
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/pandas/io/excel/_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/site-packages/openpyxl/writer/excel.py:60, in ExcelWriter.write_data(self)
#      57 archive = self._archive
#      59 props = ExtendedProperties()
# ---> 60 archive.writestr(ARC_APP, tostring(props.to_tree()))
#      62 archive.writestr(ARC_CORE, tostring(self.workbook.properties.to_tree()))
#      63 if self.workbook.loaded_theme:
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/zipfile/__init__.py:1948, in ZipFile.writestr(self, zinfo_or_arcname, data, compress_type, compresslevel)
#    1946 zinfo.file_size = len(data)            # Uncompressed size
#    1947 with self._lock:
# -> 1948     with self.open(zinfo, mode='w') as dest:
#    1949         dest.write(data)
#
# File /opt/miniconda3/envs/data-visualization/lib/python3.13/zipfile/__init__.py:1290, in _ZipWriteFile.close(self)
#    1284 else:
#    1285     # Seek backwards and write file header (which will now include
#    1286     # correct CRC and file sizes)
#    1287
#    1288     # Preserve current position in file
#    1289     self._zipfile.start_dir = self._fileobj.tell()
# -> 1290     self._fileobj.seek(self._zinfo.header_offset)
#    1291     self._fileobj.write(self._zinfo.FileHeader(self._zip64))
#    1292     self._fileobj.seek(self._zipfile.start_dir)
#
# TimeoutError: [Errno 60] Operation timed out
